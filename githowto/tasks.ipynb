# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Снимок экрана 2025-01-24 140642.png](<attachment:Снимок экрана 2025-01-24 140642.png>)

# %% [markdown]
# Before changes:
# ![image.png](attachment:image.png)

# %% [markdown]
# After changes:
# ![image.png](attachment:image.png)
